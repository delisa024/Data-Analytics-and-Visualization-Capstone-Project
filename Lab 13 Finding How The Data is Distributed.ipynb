# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Finding How The Data Is Distributed**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this lab, you will work with a cleaned dataset to perform Exploratory Data Analysis (EDA). You will examine the structure of the data, visualize key variables, and analyze trends related to developer experience, tools, job satisfaction, and other important aspects.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# - Understand the structure of the dataset.
#
# - Perform summary statistics and data visualization.
#
# - Identify trends in developer experience, tools, job satisfaction, and other key variables.

# %% [markdown]
# ### Install the required libraries

# %%
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 134.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 143.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 117.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 61.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 67.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 111.6 MB/s eta 0:00:00
# ...

# %% [markdown]
# ### Step 1: Import Libraries and Load Data

# %% [markdown]
# - Import the `pandas`, `matplotlib.pyplot`, and `seaborn` libraries.

# %% [markdown]
# - You will begin with loading the dataset. You can use the pyfetch method if working on JupyterLite. Otherwise, you can use pandas' read_csv() function directly on their local machines or cloud environments.

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the Stack Overflow survey dataset
data_url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv'
df = pd.read_csv(data_url)

# Display the first few rows of the dataset
df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# ### Step 2: Examine the Structure of the Data

# %% [markdown]
# - Display the column names, data types, and summary information to understand the data structure.
#
# - Objective: Gain insights into the dataset's shape and available variables.

# %%
## Write your code here
df.describe()
# Out:
#          ResponseId      CompTotal       WorkExp  JobSatPoints_1  \
# count  65437.000000   3.374000e+04  29658.000000    29324.000000
# mean   32719.000000  2.963841e+145     11.466957       18.581094
# std    18890.179119  5.444117e+147      9.168709       25.966221
# min        1.000000   0.000000e+00      0.000000        0.000000
# 25%    16360.000000   6.000000e+04      4.000000        0.000000
# 50%    32719.000000   1.100000e+05      9.000000       10.000000
# 75%    49078.000000   2.500000e+05     16.000000       22.000000
# max    65437.000000  1.000000e+150     50.000000      100.000000
#
#        JobSatPoints_4  JobSatPoints_5  JobSatPoints_6  JobSatPoints_7  \
# count    29393.000000    29411.000000    29450.000000     29448.00000
# mean         7.522140       10.060857       24.343232        22.96522
# std         18.422661       21.833836       27.089360        27.01774
# min          0.000000        0.000000        0.000000         0.00000
# ...

# %%
df.dtypes
# Out:
# ResponseId               int64
# MainBranch                 str
# Age                        str
# Employment                 str
# RemoteWork                 str
#                         ...
# JobSatPoints_11        float64
# SurveyLength               str
# SurveyEase                 str
# ConvertedCompYearly    float64
# JobSat                 float64
# Length: 114, dtype: object

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Age', 'Employment', 'RemoteWork', 'Check',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        ...
#        'JobSatPoints_6', 'JobSatPoints_7', 'JobSatPoints_8', 'JobSatPoints_9',
#        'JobSatPoints_10', 'JobSatPoints_11', 'SurveyLength', 'SurveyEase',
#        'ConvertedCompYearly', 'JobSat'],
#       dtype='str', length=114)

# %% [markdown]
# ### Step 3: Handle Missing Data

# %% [markdown]
# - Identify missing values in the dataset.
#
# - Impute or remove missing values as necessary to ensure data completeness.

# %%
## Write your code here
df.isnull().sum()
df.isnull().mean()*100
# Out:
# ResponseId              0.000000
# MainBranch              0.000000
# Age                     0.000000
# Employment              0.000000
# RemoteWork             16.246160
#                          ...
# JobSatPoints_11        55.002522
# SurveyLength           14.143375
# SurveyEase             14.057796
# ConvertedCompYearly    64.186928
# JobSat                 55.490013
# Length: 114, dtype: float64

# %%
df['JobSatPoints_11'] = df['JobSatPoints_11'].fillna(0.0)
df['SurveyLength'] = df['SurveyLength'].fillna('Unknown')
df['JobSat'] = df['JobSat'].fillna(df['JobSat'].median())
df['RemoteWork'] = df['RemoteWork'].fillna('Unknown')
df.isnull().mean()*100
# Out:
# ResponseId              0.000000
# MainBranch              0.000000
# Age                     0.000000
# Employment              0.000000
# RemoteWork              0.000000
#                          ...
# JobSatPoints_11         0.000000
# SurveyLength            0.000000
# SurveyEase             14.057796
# ConvertedCompYearly    64.186928
# JobSat                  0.000000
# Length: 114, dtype: float64

# %% [markdown]
# ### Step 4: Analyze Key Columns

# %% [markdown]
# - Examine key columns such as `Employment`, `JobSat` (Job Satisfaction), and `YearsCodePro` (Professional Coding Experience).
#
# - **Instruction**: Calculate the value counts for each column to understand the distribution of responses.

# %%
## Write your code here
df['Employment'].value_counts().sort_index()
# Out:
# Employment
# Employed, full-time                                                                                     39041
# Employed, full-time;Employed, part-time                                                                   212
# Employed, full-time;Independent contractor, freelancer, or self-employed                                 3557
# Employed, full-time;Independent contractor, freelancer, or self-employed;Employed, part-time              184
# Employed, full-time;Independent contractor, freelancer, or self-employed;Employed, part-time;Retired        1
#                                                                                                         ...
# Student, full-time;Student, part-time;Employed, part-time                                                   7
# Student, full-time;Student, part-time;Retired                                                               2
# ...

# %%
df['JobSat'].value_counts().sort_index()
# Out:
# JobSat
# 0.0       311
# 1.0       276
# 2.0       772
# 3.0      1165
# 4.0      1130
# 5.0      1956
# 6.0      3751
# 7.0     42690
# 8.0      7509
# 9.0      3626
# 10.0     2251
# Name: count, dtype: int64

# %%
df['YearsCodePro'].value_counts().sort_index()
# Out:
# YearsCodePro
# 1                     2639
# 10                    3251
# 11                    1312
# 12                    1777
# 13                    1127
# 14                    1082
# 15                    1635
# 16                     946
# 17                     814
# 18                     867
# 19                     516
# 2                     4168
# 20                    1549
# 21                     380
# 22                     492
# 23                     448
# 24                     632
# 25                     998
# 26                     426
# 27                     380
# 28                     342
# 29                     196
# 3                     4093
# 30                     689
# 31                     106
# 32                     194
# 33                     132
# 34                     169
# 35                     285
# 36                     119
# 37                     104
# 38                     134
# 39                      54
# ...

# %% [markdown]
# ### Step 5: Visualize Job Satisfaction (Focus on JobSat)

# %% [markdown]
# - Create a pie chart or KDE plot to visualize the distribution of `JobSat`.
#
# - Provide an interpretation of the plot, highlighting key trends in job satisfaction.

# %%
## Write your code here
# Ensure numeric and clean
df['JobSat'] = pd.to_numeric(df['JobSat'], errors='coerce')
df_clean = df.dropna(subset=['JobSat'])

job_counts = df_clean['JobSat'].value_counts().sort_index()

plt.figure()

plt.pie(
    job_counts,
    labels=job_counts.index,
    autopct='%1.1f%%'
)

plt.title('Job Satisfaction Distribution (Pie Chart)')
plt.show()

# %%
plt.figure()

sns.kdeplot(df_clean['JobSat'], fill=True)

plt.xlabel('Job Satisfaction')
plt.title('Job Satisfaction Distribution (KDE Plot)')

plt.show()

# %% [markdown]
# ### Step 6: Programming Languages Analysis

# %% [markdown]
# - Compare the frequency of programming languages in `LanguageHaveWorkedWith` and `LanguageWantToWorkWith`.
#
# - Visualize the overlap or differences using a Venn diagram or a grouped bar chart.

# %%
## Write your code here
# Drop missing values
df_lang = df.dropna(subset=['LanguageHaveWorkedWith', 'LanguageWantToWorkWith'])

# Split into lists
df_lang['LanguageHaveWorkedWith'] = df_lang['LanguageHaveWorkedWith'].str.split(';')
df_lang['LanguageWantToWorkWith'] = df_lang['LanguageWantToWorkWith'].str.split(';')

# Explode into rows
have = df_lang.explode('LanguageHaveWorkedWith')
want = df_lang.explode('LanguageWantToWorkWith')

have_counts = have['LanguageHaveWorkedWith'].value_counts()
want_counts = want['LanguageWantToWorkWith'].value_counts()
lang_compare = pd.DataFrame({
    'HaveWorkedWith': have_counts,
    'WantToWorkWith': want_counts
}).fillna(0)

# Sort by popularity
lang_compare = lang_compare.sort_values(by='HaveWorkedWith', ascending=False)
# Select top 10 languages for clarity
top_langs = lang_compare.head(10)

top_langs.plot(kind='bar')

plt.title('Programming Languages: Current vs Desired')
plt.xlabel('Language')
plt.ylabel('Count')
plt.xticks(rotation=45)

plt.legend(['Have Worked With', 'Want To Work With'])
plt.show()

# %% [markdown]
# ### Step 7: Analyze Remote Work Trends

# %% [markdown]
# - Visualize the distribution of RemoteWork by region using a grouped bar chart or heatmap.

# %%
## Write your code here

# Clean missing values
df['RemoteWork'] = df['RemoteWork'].fillna('Unknown')
df['Country'] = df['Country'].fillna('Unknown')
region_map = {
    'United States': 'North America',
    'Canada': 'North America',
    'Germany': 'Europe',
    'France': 'Europe',
    'India': 'Asia',
    'Brazil': 'South America',
    'Australia': 'Oceania'
}

df['Region'] = df['Country'].map(region_map)
df = df.dropna(subset=['Region'])
remote_region = pd.crosstab(df['Region'], df['RemoteWork'])

print(remote_region)
remote_region_pct = pd.crosstab(
    df['Region'], 
    df['RemoteWork'], 
    normalize='index'
) * 100
remote_region_pct.plot(kind='bar')

plt.title('Remote Work Distribution by Region')
plt.xlabel('Region')
plt.ylabel('Percentage')
plt.xticks(rotation=45)

plt.legend(title='Remote Work')
plt.show()
# Out:
# RemoteWork     Hybrid (some remote, some in-person)  In-person  Remote  \
# Region
# Asia                                           1196       1088     853
# Europe                                         3462       1004    1611
# North America                                   631        227     907
# Oceania                                         542        163     330
# South America                                   311        191     714
#
# RemoteWork     Unknown
# Region
# Asia              1094
# Europe             980
# North America      339
# Oceania            225
# South America      159

# %%
plt.figure(figsize=(8,6))

sns.heatmap(remote_region_pct, annot=True, cmap='Blues', fmt=".1f")

plt.title('Remote Work Trends by Region (%)')
plt.xlabel('Remote Work Type')
plt.ylabel('Region')

plt.show()

# %% [markdown]
# ### Step 8: Correlation between Job Satisfaction and Experience

# %% [markdown]
# - Analyze the correlation between overall job satisfaction (`JobSat`) and `YearsCodePro`.
#
# - Calculate the Pearson or Spearman correlation coefficient.

# %%
## Write your code here

# Convert to numeric
df['YearsCodePro'] = pd.to_numeric(df['YearsCodePro'], errors='coerce')
df['JobSat'] = pd.to_numeric(df['JobSat'], errors='coerce')

# Drop missing values
df_clean = df.dropna(subset=['YearsCodePro', 'JobSat'])
pearson_corr = df_clean['YearsCodePro'].corr(df_clean['JobSat'], method='pearson')

print(f"Pearson Correlation: {pearson_corr:.3f}")
# Out:
# Pearson Correlation: 0.074

# %% [markdown]
# ### Step 9: Cross-tabulation Analysis (Employment vs. Education Level)

# %% [markdown]
# - Analyze the relationship between employment status (`Employment`) and education level (`EdLevel`).
#
# - **Instruction**: Create a cross-tabulation using `pd.crosstab()` and visualize it with a stacked bar plot if possible.

# %%
## Write your code here
df['Employment'] = df['Employment'].fillna('Unknown')
df['EdLevel'] = df['EdLevel'].fillna('Unknown')
crosstab = pd.crosstab(df['EdLevel'], df['Employment'])
print(crosstab)

crosstab.plot(
    kind='bar',
    stacked=True,
    figsize=(10,6)
)
crosstab = pd.crosstab(
    df['EdLevel'], 
    df['Employment'], 
    normalize='index'
) * 100

print(crosstab)

plt.title('Employment Distribution by Education Level')
plt.xlabel('Education Level')
plt.ylabel('Percentage')
plt.xticks(rotation=45)

plt.legend(title='Employment', bbox_to_anchor=(1.05, 1))

plt.tight_layout()
plt.show()
# Out:
# Employment                                          Employed, full-time  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                 291
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                       4280
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                    3225
# Primary/elementary school                                            32
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                      556
# Secondary school (e.g. American high school, Ge...                  387
# Some college/university study without earning a...                  719
# Something else                                                      136
#
# Employment                                          Employed, full-time;Employed, part-time  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                       1
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                             17
# ...

# %% [markdown]
# ### Step 10: Export Cleaned Data

# %% [markdown]
# - Save the cleaned dataset to a new CSV file for further use or sharing.

# %%
## Write your code here
df.to_csv('newcleaned_dataset.csv', index=False)

# %% [markdown]
# ### Summary:

# %% [markdown]
# In this lab, you practiced key skills in exploratory data analysis, including:

# %% [markdown]
# - Examining the structure and content of the Stack Overflow survey dataset to understand its variables and data types.
#
# - Identifying and addressing missing data to ensure the dataset's quality and completeness.
#
# - Summarizing and visualizing key variables such as job satisfaction, programming languages, and remote work trends.
#
# - Analyzing relationships in the data using techniques like:
#     - Comparing programming languages respondents have worked with versus those they want to work with.
#
#     - Exploring remote work preferences by region.
#
# - Investigating correlations between professional coding experience and job satisfaction.
#
# - Performing cross-tabulations to analyze relationships between employment status and education levels.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# Rav Ahuja
# Lakshmi Holla
# Malika

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
